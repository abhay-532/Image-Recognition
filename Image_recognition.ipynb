# %% [markdown]
# Importing the required libraries

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import cifar10

# %% [markdown]
# Loading the required Dataset

# %%
# setting class names
class_names=['airplane','automobile','bird','cat','deer','dog','frog','horse','ship','truck']
#loading the dataset
(x_train,y_train),(x_test,y_test)=cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 4s 0us/step

# %%
x_train=x_train/255.0
x_test=x_test/255.0

x_train.shape, x_test.shape
# Out:
# ((50000, 32, 32, 3), (10000, 32, 32, 3))

# %% [markdown]
# Building the Convolutional Neural Network

# %%
cifar10_model=tf.keras.models.Sequential()
# First Layer
cifar10_model.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding="same", activation="relu", input_shape=[32,32,3]))
# Second Layer
cifar10_model.add(tf.keras.layers.Conv2D(filters=32,kernel_size=3,padding="same", activation="relu"))
# Max Pooling Layer
cifar10_model.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2,padding='valid'))
# Third Layer
cifar10_model.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding="same", activation="relu"))
# Fourth Layer
cifar10_model.add(tf.keras.layers.Conv2D(filters=64,kernel_size=3,padding="same", activation="relu"))
# Max Pooling Layer
cifar10_model.add(tf.keras.layers.MaxPool2D(pool_size=2,strides=2,padding='valid'))
# Flattening Layer
cifar10_model.add(tf.keras.layers.Flatten())
# Droput Layer
cifar10_model.add(tf.keras.layers.Dropout(0.5,noise_shape=None,seed=None))
# Adding the first fully connected layer
cifar10_model.add(tf.keras.layers.Dense(units=128,activation='relu'))
# Output Layer
cifar10_model.add(tf.keras.layers.Dense(units=10,activation='softmax'))

cifar10_model.summary()

cifar10_model.compile(loss="sparse_categorical_crossentropy", optimizer="Adam", metrics=["sparse_categorical_accuracy"])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 4096)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 4096)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               524416
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 591,274
# Trainable params: 591,274
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Training the Model with the train dataset

# %%
cifar10_model.fit(x_train,y_train,epochs=20)
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 38s 4ms/step - loss: 1.3943 - sparse_categorical_accuracy: 0.4937
# Epoch 2/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.9893 - sparse_categorical_accuracy: 0.6497
# Epoch 3/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.8382 - sparse_categorical_accuracy: 0.7045
# Epoch 4/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.7510 - sparse_categorical_accuracy: 0.7364
# Epoch 5/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6832 - sparse_categorical_accuracy: 0.7607
# Epoch 6/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.6268 - sparse_categorical_accuracy: 0.7808
# Epoch 7/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.5849 - sparse_categorical_accuracy: 0.7947
# Epoch 8/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.5489 - sparse_categorical_accuracy: 0.8039
# Epoch 9/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.5219 - sparse_categorical_accuracy: 0.8145
# Epoch 10/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.4908 - sparse_categorical_accuracy: 0.8259
# Epoch 11/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.4648 - sparse_categorical_accuracy: 0.8339
# Epoch 12/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.4425 - sparse_categorical_accuracy: 0.8421
# Epoch 13/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.4246 - sparse_categorical_accuracy: 0.8476
# Epoch 14/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.4032 - sparse_categorical_accuracy: 0.8574
# Epoch 15/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3917 - sparse_categorical_accuracy: 0.8595
# Epoch 16/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3725 - sparse_categorical_accuracy: 0.8671
# Epoch 17/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3687 - sparse_categorical_accuracy: 0.8704
# Epoch 18/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3557 - sparse_categorical_accuracy: 0.8748
# Epoch 19/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3432 - sparse_categorical_accuracy: 0.8782
# Epoch 20/20
# 1563/1563 [==============================] - 7s 4ms/step - loss: 0.3273 - sparse_categorical_accuracy: 0.8835

# %%
test_loss, test_accuracy = cifar10_model.evaluate(x_test, y_test)
print("Test accuracy: {}".format(test_accuracy))
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.6843 - sparse_categorical_accuracy: 0.7881
# Test accuracy: 0.788100004196167
